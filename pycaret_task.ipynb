# %%
#loading data from pycaret
from pycaret.datasets import get_data

# %%
# classificatin example
diabetes_df = get_data("diabetes")
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
# ...

# %%
from pycaret.classification import *
clf = setup(data = diabetes_df, target= 'Class variable')
# Out:
# <style type="text/css">
# #T_42553_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_42553">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_42553_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_42553_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_42553_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_42553_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_42553_row0_col1" class="data row0 col1" >8224</td>
#     </tr>
#     <tr>
#       <th id="T_42553_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_42553_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_42553_row1_col1" class="data row1 col1" >Class variable</td>
#     </tr>
#     <tr>
#       <th id="T_42553_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
#compare models
compare_models()
# Out:
# <style type="text/css">
# #T_bedde th {
#   text-align: left;
# }
# ...

# %% [markdown]
# Regression problem

# %%
boston_df=get_data('boston')
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
from pycaret.regression import *
reg= setup(data= boston_df, target='medv')
# Out:
# <style type="text/css">
# #T_e3538_row7_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e3538">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e3538_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e3538_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e3538_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e3538_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_e3538_row0_col1" class="data row0 col1" >440</td>
#     </tr>
#     <tr>
#       <th id="T_e3538_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e3538_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e3538_row1_col1" class="data row1 col1" >medv</td>
#     </tr>
#     <tr>
#       <th id="T_e3538_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
#compare models
compare_models()
# Out:
# <style type="text/css">
# #T_07110 th {
#   text-align: left;
# }
# ...

# %%
reg_model = create_model('gbr')
# Out:
# <style type="text/css">
# #T_cfe7f_row10_col0, #T_cfe7f_row10_col1, #T_cfe7f_row10_col2, #T_cfe7f_row10_col3, #T_cfe7f_row10_col4, #T_cfe7f_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_cfe7f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cfe7f_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_cfe7f_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_cfe7f_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_cfe7f_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_cfe7f_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_cfe7f_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
reg_model
# Out:
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='squared_error',
#                           max_depth=3, max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_samples_leaf=1,
#                           min_samples_split=2, min_weight_fraction_leaf=0.0,
#                           n_estimators=100, n_iter_no_change=None,
#                           random_state=440, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
reg_model.get_params
# Out:
# <bound method BaseEstimator.get_params of GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='squared_error',
#                           max_depth=3, max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_samples_leaf=1,
#                           min_samples_split=2, min_weight_fraction_leaf=0.0,
#                           n_estimators=100, n_iter_no_change=None,
#                           random_state=440, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)>

# %%
# hyper tuning of models
#reg_model_hypertune = tune_model('gbr', n_iter=50, optimize='mae')
tuned_reg = tune_model(reg_model)
# Out:
# <style type="text/css">
# #T_453fd_row10_col0, #T_453fd_row10_col1, #T_453fd_row10_col2, #T_453fd_row10_col3, #T_453fd_row10_col4, #T_453fd_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_453fd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_453fd_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_453fd_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_453fd_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_453fd_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_453fd_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_453fd_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %% [markdown]
# #clustering

# %%
jewellery = get_data('jewellery')
# Out:
#    Age  Income  SpendingScore       Savings
# 0   58   77769       0.791329   6559.829923
# 1   59   81799       0.791082   5417.661426
# 2   62   74751       0.702657   9258.992965
# 3   59   74373       0.765680   7346.334504
# 4   87   17760       0.348778  16869.507130

# %%
from pycaret.clustering import *
clust_algo = setup(jewellery)
# Out:
# <style type="text/css">
# #T_36f7b_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_36f7b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_36f7b_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_36f7b_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_36f7b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_36f7b_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_36f7b_row0_col1" class="data row0 col1" >1544</td>
#     </tr>
#     <tr>
#       <th id="T_36f7b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_36f7b_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_36f7b_row1_col1" class="data row1 col1" >(505, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_36f7b_level0_row2" class="row_heading level0 row2" >2</th>
# ...
